# %%
import pandas as pd

# %%
tamil_train_data = pd.read_csv("tamil_train - tamil_train.tsv",sep='\t')
tamil_train_data.head()
# Out:
#                                                text  category
# 0          Trailer late ah parthavanga like podunga  Positive
# 1        Move pathutu vanthu trailer pakurvnga yaru  Positive
# 2          Puthupetai dhanush  ah yarellam pathinga  Positive
# 3  Dhanush oda character ,puthu sa erukay , mass ta  Positive
# 4  vera level ippa pesungada mokka nu thalaivaaaaaa  Positive

# %%
tamil_val_data = pd.read_csv("tamil_dev - tamil_dev.tsv",sep='\t')
tamil_val_data.head()
# Out:
#                                                 text        category
# 0  Daily likes & views pakka vanthavaga ellarukum...        Positive
# 1  25 k dislikes ethuku da intha trailerku poi ap...        Negative
# 2                 #Lyca unna nenacha pavama iruku ya  Mixed_feelings
# 3            It looks like Hindi movie amitab bachan        Positive
# 4  Thalaivarukku nejamavey vayasaagiduchu... siva...        Positive

# %%
tamil_train_data.describe()
# Out:
#                          text  category
# count                   11335     11335
# unique                  11237         5
# top     Kajal  Fans Subscribe  Positive
# freq                        6      7627

# %%
import matplotlib.pyplot as plt

# %%
tamil_test_data = pd.read_csv("tamil_test_answer - tamil_test_answer.tsv",sep='\t')
tamil_test_data.head()
# Out:
#           id                                               text  \
# 0  ta_sent_1         Yarayellam FDFS ppga ippove ready agitinga
# 1  ta_sent_2  Ennada viswasam mersal sarkar madhri time la l...
# 2  ta_sent_3  yuvan vera level ya .... valuable script. SK i...
# 3  ta_sent_4  70 vayasulayum thanoda rasigargala sandhosapad...
# 4  ta_sent_5      all the best anna...Telugu makkal selvan fans
#
#          category
# 0        Positive
# 1        Positive
# 2        Positive
# 3  Mixed_feelings
# 4        Positive

# %%
tamil_test_data.groupby('category').describe()
# Out:
#                   id                          text         \
#                count unique         top freq count unique
# category
# Mixed_feelings   377    377   ta_sent_4    1   377    377
# Negative         424    424  ta_sent_15    1   424    424
# Positive        2075   2075   ta_sent_1    1  2075   2069
# not-Tamil        100    100   ta_sent_9    1   100    100
# unknown_state    173    173   ta_sent_8    1   173    173
#
#
#                                                               top freq
# category
# Mixed_feelings  70 vayasulayum thanoda rasigargala sandhosapad...    1
# Negative        Padu mokkai, ean thalayai kooni kondu nikkuthu...    1
# Positive        Thalaivaa Thalaivaa Thalaivaa Thalaivaa Thalai...    2
# not-Tamil                       Saamy2 hindi dubbed kb la rahe ho    1
# unknown_state   Vera level next movie Ida vida bayangaram ha i...    1

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
x_train = tamil_train_data.iloc[:,0].values
y_train = tamil_train_data.iloc[:,1].values

x_val = tamil_val_data.iloc[:,0].values
y_val = tamil_val_data.iloc[:,1].values

x_test = tamil_test_data.iloc[:,1].values
y_test = tamil_test_data.iloc[:,2].values

# %%
print(len(x_train)," ", len(x_val) ," ", len(x_test))
print(len(y_train)," ", len(y_val) ," ", len(y_test))
# Out:
# 11335   1260   3149
# 11335   1260   3149

# %%
import numpy as np
X = np.append(x_train,x_val,axis=0)
X = np.append(X,x_test,axis=0)
Y = np.append(y_train,y_val,axis=0)
Y = np.append(Y,y_test,axis=0)

# %%
import re

processed_tweets = []

def pre_processing(X):
  for tweet in range(0, len(X)):
    # Remove all the special characters
    processed_tweet = re.sub(r'\W', ' ', str(X[tweet]))

    # remove all single characters
    processed_tweet = re.sub(r'\s+[a-zA-Z]\s+', ' ', processed_tweet)

    # Remove single characters from the start
    #processed_tweet = re.sub(r'\^[a-zA-Z]\s+', ' ', processed_tweet)

    # Substituting multiple spaces with single space
    processed_tweet= re.sub(r'\s+', ' ', processed_tweet, flags=re.I)

    # Converting to Lowercase
    processed_tweet = processed_tweet.lower()

    processed_tweets.append(processed_tweet)

# %%
pre_processing(X)
#processed_tweets

# %%
processed_labels = []

def pre_processing_l(Y):
  for i in range(0, len(Y)):
    # Removing multiple spaces
    processed_label= re.sub(r'\s+', '', str(Y[i]), flags=re.I)

    processed_labels.append(processed_label)

# %%
pre_processing_l(Y)
#processed_labels

# %%
X_train = X[:len(x_train)]
Y_train = Y[:len(y_train)]

X_val = X[len(x_train) : len(x_train)+len(x_val)]
Y_val = Y[len(y_train) : len(y_train)+len(y_val)]

print(len(X_train))
print(len(Y_train))

print(len(X_val))
print(len(Y_val))

X_test = X[len(x_train)+len(x_val) : ]
Y_test = Y[len(y_train)+len(y_val) : ]

print(len(X_test))
print(len(Y_test))
# Out:
# 11335
# 11335
# 1260
# 1260
# 3149
# 3149

# %%
# !pip install fasttext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pybind11-2.12.0-py3-none-any.whl (234 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4227137 sha256=747a7b36c6db5ebebe2dbfa25485c49bd19f8eab1a0f64dc461e0d6b0dbf3272
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# ...

# %%
tamil_train_data['category'] = '__label__' + tamil_train_data['category'].astype(str)
tamil_train_data.head(5)
# Out:
#                                                text           category
# 0          Trailer late ah parthavanga like podunga  __label__Positive
# 1        Move pathutu vanthu trailer pakurvnga yaru  __label__Positive
# 2          Puthupetai dhanush  ah yarellam pathinga  __label__Positive
# 3  Dhanush oda character ,puthu sa erukay , mass ta  __label__Positive
# 4  vera level ippa pesungada mokka nu thalaivaaaaaa  __label__Positive

# %%
tamil_train_data['category_description'] = tamil_train_data['category'] + ' ' + tamil_train_data['text']
tamil_train_data.head(3)
# Out:
#                                          text           category  \
# 0    Trailer late ah parthavanga like podunga  __label__Positive
# 1  Move pathutu vanthu trailer pakurvnga yaru  __label__Positive
# 2    Puthupetai dhanush  ah yarellam pathinga  __label__Positive
#
#                                 category_description
# 0  __label__Positive Trailer late ah parthavanga ...
# 1  __label__Positive Move pathutu vanthu trailer ...
# 2  __label__Positive Puthupetai dhanush  ah yarel...

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(tamil_train_data, test_size=0.2)

tamil_test_data['category'] = '__label__' + tamil_test_data['category'].astype(str)
tamil_test_data.head(5)
tamil_test_data['category_description'] = tamil_test_data['category'] + ' ' + tamil_test_data['text']
tamil_test_data.head(3)
# Out:
#           id                                               text  \
# 0  ta_sent_1         Yarayellam FDFS ppga ippove ready agitinga
# 1  ta_sent_2  Ennada viswasam mersal sarkar madhri time la l...
# 2  ta_sent_3  yuvan vera level ya .... valuable script. SK i...
#
#             category                               category_description
# 0  __label__Positive  __label__Positive Yarayellam FDFS ppga ippove ...
# 1  __label__Positive  __label__Positive Ennada viswasam mersal sarka...
# 2  __label__Positive  __label__Positive yuvan vera level ya .... val...

# %%
tamil_train_data.to_csv("a.train", columns=["category_description"], index=False, header=False)
tamil_test_data.to_csv("tamil_test - tamil_test.tsv", columns=["category_description"], index=False, header=False)

# %%
import fasttext

model = fasttext.train_supervised(input="a.train")
model.test("tamil_test - tamil_test.tsv")
# Out:
# (2962, 0.6731937879810939, 0.6731937879810939)

# %%
model.predict=("Trailer late ah parthavanga like")

# %%
model.predict=("Trailer late ah parthavanga like")
